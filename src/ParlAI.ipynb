# %% [markdown]
# ## Parl AI

# %%
# With Python 3.9
# ! pip install --upgrade pip "setuptools<82" wheel
# ! pip install parlai
# ! pip install matplotlib
# ! pip install spacy==3.6.0
# ! pip install nltk

# %%
# Download the data
# ! parlai display_data -t msc --include-last-session True
# ! parlai display_data -t msc:PersonaSummary --include-last-session True

# %%
! parlai display_data -t msc:PersonaSummary --include-last-session True -n 10
# Out:
# /usr/local/anaconda3/envs/parlai/lib/python3.9/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# 17:17:41 | Opt:
# 17:17:41 |     allow_missing_init_opts: False
# 17:17:41 |     batchsize: 1
# 17:17:41 |     datapath: /usr/local/anaconda3/envs/parlai/lib/python3.9/site-packages/data
# 17:17:41 |     datatype: train:ordered
# 17:17:41 |     dict_class: None
# 17:17:41 |     display_add_fields:
# 17:17:41 |     download_path: None
# 17:17:41 |     dynamic_batching: None
# 17:17:41 |     hide_labels: False
# 17:17:41 |     ignore_agent_reply: True
# 17:17:41 |     image_cropsize: 224
# 17:17:41 |     image_mode: raw
# 17:17:41 |     image_size: 256
# 17:17:41 |     include_last_session: True
# 17:17:41 |     init_model: None
# 17:17:41 |     init_opt: None
# 17:17:41 |     is_debug: False
# 17:17:41 |     loglevel: info
# 17:17:41 |     max_display_len: 1000
# ...

# %%
# from parlai.core.params import ParlaiParser
# from parlai.core.worlds import create_task

# # Set up the arguments for the MSC task
# parser = ParlaiParser(True, True)
# opt_summary = parser.parse_kwargs(
#     task='msc:PersonaSummary',
#     datatype='train:ordered',       # Can be 'train', 'valid', or 'test'
#     include_last_session=True,      # Include session 5
#     model='repeat_label'            # Use a dummy agent to interact with the data
# )

# # Create a basic repeating agent and bind it to the dataset
# # (The "world" manages the interaction between the dataset and your agent)
# from parlai.core.agents import create_agent
# agent_summary = create_agent(opt_summary, requireModelExists=False)
# world_summary = create_task(opt_summary, [agent_summary])
